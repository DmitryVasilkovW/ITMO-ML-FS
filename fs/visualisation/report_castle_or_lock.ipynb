# %%
from fs.evaluator.model_evaluator import ModelEvaluator
from fs.visualisation.data_clustering import show_data
from fs.visualisation.dataset_info import show_dataset_info
from fs.visualisation.plot import show_plot
import pandas as pd

# %% [markdown]
# # For dataset castle or lock

# %% [markdown]
# ### Dataset info

# %%
show_dataset_info()
# Out:
# Dataset content
#    Label                                               Text
# 0      1  Альксар в Сегвии — замок испанских королей в и...
# 1      1  Замок Бруэм (англ. Brougham /bru()m/[1], иногд...
# 2      1  Верхний замок: 1. Западная башня. 2. Южная баш...
# 3      1  Дублинский замок (ирл. Caislen Bhaile tha Clia...
# 4      1  Замок Бельмонте (исп. Castillo de Belmonte) — ...
#
# training sample size
# Number of samples: 58, number of features: 1000
#
# testing sample size
# Number of samples: 26, number of features: 1000
#
# vector data size
# Number of samples: 84, number of features: 1000

# %% [markdown]
# ### Plot

# %%
show_plot()

# %% [markdown]
# ### Accuracy comparison

# %%
res = ModelEvaluator.get_results()
print(pd.DataFrame(res))
# Out:
#                            Random Forest       SVM  Naive Bayes
# Without Feature Selection       0.961538  1.000000     1.000000
# Filter                          1.000000  0.961538     0.961538
# Embedded                        1.000000  1.000000     1.000000
# Wrapper                         1.000000  0.961538     1.000000

# %% [markdown]
# ### Data clustering

# %%
show_data()
# Out:
# Adjusted Rand Index before selecting features: 0.18315475178109114
# Adjusted Rand Index after selecting traits: 0.06421137813576228
# Silhouette before selecting features: 0.15679112076759338
# Silhouette after selecting the traits: 0.26410478353500366
